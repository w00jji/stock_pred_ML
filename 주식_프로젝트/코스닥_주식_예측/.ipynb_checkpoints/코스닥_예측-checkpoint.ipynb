# %% [markdown]
# ### 코스닥 예측

# %% [markdown]
# ### 모델링

# %%
import FinanceDataReader as fdr
import numpy as np
import pandas as pd
import xgboost as xgb
import joblib
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

# CSV 파일에서 주식 코드 목록 불러오기
kosdak = pd.read_csv('KOSDAQ_result.csv')
# stock_codes = kosdak['Code'].astype(str).str.zfill(6).tolist()  # 주식 코드 목록 생성 (0으로 채우기)

# 주식 코드 전체 선택
stock_codes = kosdak['Code'].astype(str).str.zfill(6).tolist()

# 전체 주식 코드 목록 출력
print("Stock Codes:")
print(stock_codes)

# 각 기업별 모델을 저장할 딕셔너리
models = {}

for code in stock_codes:
    try:
        df = fdr.DataReader(code).dropna()  # 데이터 불러오기 및 결측값 제거
        if not df.empty:
            # 가격 변화율 계산
            # df['Change'] = df['Close'].pct_change()
            df = df.dropna()
            # EMA 계산 및 MACD, Signal Line 생성
            df['ema_10'] = df['Close'].ewm(span=10, adjust=False).mean()
            df['ema_12'] = df['Close'].ewm(span=12, adjust=False).mean()
            df['ema_26'] = df['Close'].ewm(span=26, adjust=False).mean()
            df['ema_30'] = df['Close'].ewm(span=30, adjust=False).mean()
            df['MACD'] = df['ema_12'] - df['ema_26']
            df['Signal Line'] = df['MACD'].ewm(span=9, adjust=False).mean()
            # Signals 계산
            signals = 2  # 첫 번째 신호는 비교할 이전 데이터가 없기 때문에 2로 설정
#             for i in range(1, len(df)):
#                 if ((df['MACD'].iloc[i-1] < df['Signal Line'].iloc[i-1]) and (df['MACD'].iloc[i] > df['Signal Line'].iloc[i])):# or \
#                #    ((df['ema_10'].iloc[i-1] < df['ema_30'].iloc[i-1]) and (df['ema_10'].iloc[i] > df['ema_30'].iloc[i])):
#                     signals.append(1)  # 매수 신호
#                 elif ((df['MACD'].iloc[i-1] > df['Signal Line'].iloc[i-1]) and (df['MACD'].iloc[i] < df['Signal Line'].iloc[i])):# or \
#               #       ((df['ema_10'].iloc[i-1] > df['ema_30'].iloc[i-1]) and (df['ema_10'].iloc[i] < df['ema_30'].iloc[i])):
#                     signals.append(0)  # 매도 신호
#                 else:
#                     signals.append(2)  # 교차 없음
            df['Signal'] = signals
            # Position 열 초기화
            df['Position'] = 0
            for i in range(0, len(df), 100):
                avg_volume = df.iloc[i:i+100]['Volume'].mean()
                df.iloc[i:i+100, df.columns.get_loc('Position')] = np.where(df.iloc[i:i+100]['Volume'] > avg_volume, 1, 0)
                
            # 매수/매도 신호 업데이트
            df['Signal'] = np.where((df['Position'] == 1) & (df['Change'] < 0) & (df['Signal'] == 2), 1, df['Signal'])  # 매수
            df['Signal'] = np.where((df['Position'] == 1) & (df['Change'] > 0) & (df['Signal'] == 2), 0, df['Signal'])  # 매도
            
            # 볼린저 밴드 계산
            window = 5  # 이동평균 기간
            df['SMA'] = df['Close'].rolling(window=window).mean()  # 단순 이동평균
            df['STD'] = df['Close'].rolling(window=window).std()   # 표준편차
            df['Upper Band'] = df['SMA'] + (df['STD'] * 2)       # 상단 밴드
            df['Lower Band'] = df['SMA'] - (df['STD'] * 2)      # 하단 밴드
            
            # 결측값 제거
            df = df.dropna()
            # Position2 및 Position3 열 초기화
            df[['Position2', 'Position3']] = 0
            # 과매수 및 과매도 구간
            df['Position2'] = np.where(df['Close'] >= df['Upper Band'], 1, df['Position2'])  # 과매수 구간
            df['Position3'] = np.where(df['Close'] <= df['Lower Band'], 1, df['Position3'])  # 과매도 구간
            # 매수/매도 신호 업데이트
            df['Signal'] = np.where((df['Position2'] == 1) & (df['Signal'] == 2), 0, df['Signal'])  # 매도 추천
            df['Signal'] = np.where((df['Position3'] == 1) & (df['Signal'] == 2), 1, df['Signal'])  # 매수 추천

            
            # 불필요한 열 제거
            columns_to_remove = ['ema_10', 'ema_12', 'ema_26', 'ema_30', 'MACD', 'Signal Line', 'Position', 'SMA', 'STD', 'Upper Band', 'Lower Band', 'Position2', 'Position3']
            df = df.drop(columns=columns_to_remove)

            df.drop(columns=['Change'],inplace=True) # Recall이 너무 높아 삭제하는 열 
            
            # 다시 NaN 값 제거
            df = df.dropna()
            X = df.iloc[:,:-1]
            y = df['Signal']
            df['Signal'] = df['Signal'].shift(-1)
            df = df.dropna(subset=['Signal'])
            
             df.drop(['2024-08-22'],inplace=True)

            
            # 데이터 분할 (훈련 데이터와 테스트 데이터)
            X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42, stratify=y)
            # XGBoost 분류 모델 생성 및 학습
            model = xgb.XGBClassifier(
                objective='multi:softmax',
                eval_metric='mlogloss',
                learning_rate=0.1,
                n_estimators=100,
                max_depth=5,
                subsample=0.8,
                colsample_bytree=0.8,
                num_class=3,  # 클래스 수 (매수, 매도, 신호 없음)
                random_state=42
            )
            model.fit(X_train, Y_train)
            # 테스트 데이터에 대해 예측 수행
            Y_pred = model.predict(X_test)
            # 모델 평가
            accuracy = accuracy_score(Y_test, Y_pred)
            conf_matrix = confusion_matrix(Y_test, Y_pred)
            class_report = classification_report(Y_test, Y_pred)
            # 모델 저장
            model_filename = f'model_{code}.joblib'
            joblib.dump(model, model_filename)
            models[code] = model_filename
            # 결과 출력
            print(f"Model for code {code} saved as {model_filename}")
            print(f"Accuracy for code {code}: {accuracy}")
            print(f"Confusion Matrix for code {code}:\n{conf_matrix}")
            print(f"Classification Report for code {code}:\n{class_report}")
    except Exception as e:
        print(f"Error processing code {code}: {e}")
# Out:
# Stock Codes:
# ['041190', '015750', '215200', '025980', '095660', '215000', '290650', '099320', '006730', '101160', '023160', '013030', '043150', '243070', '297890', '230360', '035890', '045100', '041830', '083450', '018310', '267980', '060250', '265520', '126700', '050890', '035600', '051370', '054950', '299900', '211050', '148150', '118990', '078150', '108230', '950170', '054450', '051500', '052400', '236200', '083310', '190510', '194700', '377450', '023760', '067280', '046440', '092730', '136540', '123410', '214180', '036190', '023910', '091580', '298540', '079960', '009300', '418470', '023600', '452400', '950190', '203650', '259630', '285490', '445180', '038110', '264450', '033290', '099440', '060560', '353810', '092460', '066620', '100700', '382800', '067900', '066700', '069510', '013310', '124560', '137950', '332570', '021080', '215360', '066590', '005990', '058630', '071200', '053700', '035610', '011560', '089850', '142210', '352090', '036630', '019590', '042500', '043260', '417790', '302430', '111710', '234300', '065710', '086670', '059210', '024880', '054040', '038460', '012790', '263690', '014200', '009780', '241520', '122310', '036640', '052790', '216050', '208140', '036670', '339950', '038680', '158430', '048430', '115440', '007370', '024800', '155650', '094970', '130580', '054930', '241790', '224110', '082210', '212560', '090410', '250000', '105760', '094840', '271830', '053270', '038010', '010240', '039420', '092300', '019540', '100030', '227950', '122690', '440290', '067920', '204020', '088910', '263920', '263770', '098120', '263020', '003310', '019770', '332370', '246690', '111870', '066360', '046310', '025880', '078590', '340440', '131090', '267790', '099410', '290270', '052460', '020180', '297570', '362990', '006920', '080470', '039310', '042940', '113810', '154040', '208350', '043590', '053060', '335870']
# Model for code 041190 saved as model_041190.joblib
# Accuracy for code 041190: 0.8147321428571429
# Confusion Matrix for code 041190:
# [[ 150    5  129]
#  [  29   48  120]
#  [  36   13 1262]]
# Classification Report for code 041190:
#               precision    recall  f1-score   support
#
#            0       0.70      0.53      0.60       284
#            1       0.73      0.24      0.37       197
#            2       0.84      0.96      0.89      1311
#
#     accuracy                           0.81      1792
#    macro avg       0.75      0.58      0.62      1792
# weighted avg       0.80      0.81      0.79      1792
#
# Model for code 015750 saved as model_015750.joblib
# Accuracy for code 015750: 0.7570872707059477
# Confusion Matrix for code 015750:
# [[ 147   16  152]
#  [  54   51  150]
#  [  47   18 1164]]
# Classification Report for code 015750:
#               precision    recall  f1-score   support
#
#            0       0.59      0.47      0.52       315
#            1       0.60      0.20      0.30       255
#            2       0.79      0.95      0.86      1229
#
#     accuracy                           0.76      1799
#    macro avg       0.66      0.54      0.56      1799
# weighted avg       0.73      0.76      0.72      1799
#
# Model for code 215200 saved as model_215200.joblib
# Accuracy for code 215200: 0.8180494905385735
# Confusion Matrix for code 215200:
# [[ 59  30  24]
#  [ 30  50  24]
#  [  7  10 453]]
# Classification Report for code 215200:
#               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56       113
#            1       0.56      0.48      0.52       104
#            2       0.90      0.96      0.93       470
#
#     accuracy                           0.82       687
#    macro avg       0.69      0.66      0.67       687
# weighted avg       0.80      0.82      0.81       687
#
# Model for code 025980 saved as model_025980.joblib
# Accuracy for code 025980: 0.763201778765981
# Confusion Matrix for code 025980:
# [[ 103   16  170]
#  [  37   36  163]
#  [  22   18 1234]]
# Classification Report for code 025980:
#               precision    recall  f1-score   support
#
#            0       0.64      0.36      0.46       289
#            1       0.51      0.15      0.24       236
#            2       0.79      0.97      0.87      1274
#
#     accuracy                           0.76      1799
#    macro avg       0.65      0.49      0.52      1799
# weighted avg       0.73      0.76      0.72      1799
#
# Model for code 095660 saved as model_095660.joblib
# Accuracy for code 095660: 0.7921259842519685
# Confusion Matrix for code 095660:
# [[113  24  66]
#  [ 23  75  87]
#  [ 36  28 818]]
# Classification Report for code 095660:
#               precision    recall  f1-score   support
#
#            0       0.66      0.56      0.60       203
#            1       0.59      0.41      0.48       185
#            2       0.84      0.93      0.88       882
#
#     accuracy                           0.79      1270
#    macro avg       0.70      0.63      0.66      1270
# weighted avg       0.78      0.79      0.78      1270
#
# Model for code 215000 saved as model_215000.joblib
# Accuracy for code 215000: 0.7893217893217893
# Confusion Matrix for code 215000:
# [[ 38  16  46]
#  [ 12  49  47]
#  [  8  17 460]]
# Classification Report for code 215000:
#               precision    recall  f1-score   support
#
#            0       0.66      0.38      0.48       100
#            1       0.60      0.45      0.52       108
#            2       0.83      0.95      0.89       485
#
#     accuracy                           0.79       693
#    macro avg       0.69      0.59      0.63       693
# weighted avg       0.77      0.79      0.77       693
#
# Model for code 290650 saved as model_290650.joblib
# Accuracy for code 290650: 0.8018648018648019
# Confusion Matrix for code 290650:
# [[ 57   7  13]
#  [ 14  30  25]
#  [ 15  11 257]]
# Classification Report for code 290650:
#               precision    recall  f1-score   support
#
#            0       0.66      0.74      0.70        77
#            1       0.62      0.43      0.51        69
#            2       0.87      0.91      0.89       283
#
#     accuracy                           0.80       429
#    macro avg       0.72      0.69      0.70       429
# weighted avg       0.79      0.80      0.79       429
#
# Model for code 099320 saved as model_099320.joblib
# Accuracy for code 099320: 0.7516666666666667
# Confusion Matrix for code 099320:
# [[ 75  10 111]
#  [ 24  33 109]
#  [ 22  22 794]]
# Classification Report for code 099320:
#               precision    recall  f1-score   support
#
#            0       0.62      0.38      0.47       196
#            1       0.51      0.20      0.29       166
#            2       0.78      0.95      0.86       838
#
#     accuracy                           0.75      1200
#    macro avg       0.64      0.51      0.54      1200
# weighted avg       0.72      0.75      0.72      1200
#
# Model for code 006730 saved as model_006730.joblib
# Accuracy for code 006730: 0.8010005558643691
# Confusion Matrix for code 006730:
# [[ 147   23  109]
#  [  37   99  118]
#  [  38   33 1195]]
# Classification Report for code 006730:
#               precision    recall  f1-score   support
#
#            0       0.66      0.53      0.59       279
#            1       0.64      0.39      0.48       254
#            2       0.84      0.94      0.89      1266
#
#     accuracy                           0.80      1799
#    macro avg       0.71      0.62      0.65      1799
# weighted avg       0.78      0.80      0.79      1799
#
# Model for code 101160 saved as model_101160.joblib
# Accuracy for code 101160: 0.7856547122602169
# Confusion Matrix for code 101160:
# [[ 81  19  87]
#  [ 23  58  89]
#  [ 21  18 803]]
# Classification Report for code 101160:
#               precision    recall  f1-score   support
#
#            0       0.65      0.43      0.52       187
#            1       0.61      0.34      0.44       170
#            2       0.82      0.95      0.88       842
#
#     accuracy                           0.79      1199
#    macro avg       0.69      0.58      0.61      1199
# weighted avg       0.76      0.79      0.76      1199
#
# Model for code 023160 saved as model_023160.joblib
# Accuracy for code 023160: 0.7926625903279599
# Confusion Matrix for code 023160:
# [[ 189   17  107]
#  [  47  111  109]
#  [  41   52 1126]]
# Classification Report for code 023160:
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.64       313
#            1       0.62      0.42      0.50       267
#            2       0.84      0.92      0.88      1219
#
#     accuracy                           0.79      1799
#    macro avg       0.71      0.65      0.67      1799
# weighted avg       0.78      0.79      0.78      1799
#
# Model for code 013030 saved as model_013030.joblib
# Accuracy for code 013030: 0.7759866592551418
# Confusion Matrix for code 013030:
# [[ 173   12  134]
#  [  66   66  126]
#  [  44   21 1157]]
# Classification Report for code 013030:
#               precision    recall  f1-score   support
#
#            0       0.61      0.54      0.57       319
#            1       0.67      0.26      0.37       258
#            2       0.82      0.95      0.88      1222
#
#     accuracy                           0.78      1799
#    macro avg       0.70      0.58      0.61      1799
# weighted avg       0.76      0.78      0.75      1799
#
# Model for code 043150 saved as model_043150.joblib
# Accuracy for code 043150: 0.7818867924528302
# Confusion Matrix for code 043150:
# [[129   3 101]
#  [ 31  44 114]
#  [ 28  12 863]]
# Classification Report for code 043150:
#               precision    recall  f1-score   support
#
#            0       0.69      0.55      0.61       233
#            1       0.75      0.23      0.35       189
#            2       0.80      0.96      0.87       903
#
#     accuracy                           0.78      1325
#    macro avg       0.74      0.58      0.61      1325
# weighted avg       0.77      0.78      0.75      1325
#
# Model for code 243070 saved as model_243070.joblib
# Accuracy for code 243070: 0.7887788778877888
# Confusion Matrix for code 243070:
# [[ 40   9  39]
#  [ 17  31  39]
#  [  9  15 407]]
# Classification Report for code 243070:
#               precision    recall  f1-score   support
#
#            0       0.61      0.45      0.52        88
#            1       0.56      0.36      0.44        87
#            2       0.84      0.94      0.89       431
#
#     accuracy                           0.79       606
#    macro avg       0.67      0.59      0.61       606
# weighted avg       0.77      0.79      0.77       606
#
# Model for code 297890 saved as model_297890.joblib
# Accuracy for code 297890: 0.8409090909090909
# Confusion Matrix for code 297890:
# [[ 27   2  19]
#  [ 10  11  10]
#  [  6   2 221]]
# Classification Report for code 297890:
#               precision    recall  f1-score   support
#
#            0       0.63      0.56      0.59        48
#            1       0.73      0.35      0.48        31
#            2       0.88      0.97      0.92       229
#
#     accuracy                           0.84       308
#    macro avg       0.75      0.63      0.66       308
# weighted avg       0.83      0.84      0.83       308
#
# Model for code 230360 saved as model_230360.joblib
# Accuracy for code 230360: 0.8111298482293423
# Confusion Matrix for code 230360:
# [[ 47  17  30]
#  [  9  33  40]
#  [  4  12 401]]
# Classification Report for code 230360:
#               precision    recall  f1-score   support
#
#            0       0.78      0.50      0.61        94
#            1       0.53      0.40      0.46        82
#            2       0.85      0.96      0.90       417
#
#     accuracy                           0.81       593
#    macro avg       0.72      0.62      0.66       593
# weighted avg       0.80      0.81      0.80       593
#
# Model for code 035890 saved as model_035890.joblib
# Accuracy for code 035890: 0.7798777098387993
# Confusion Matrix for code 035890:
# [[ 152   12  138]
#  [  37   36  142]
#  [  45   22 1215]]
# Classification Report for code 035890:
#               precision    recall  f1-score   support
#
#            0       0.65      0.50      0.57       302
#            1       0.51      0.17      0.25       215
#            2       0.81      0.95      0.88      1282
#
#     accuracy                           0.78      1799
#    macro avg       0.66      0.54      0.56      1799
# weighted avg       0.75      0.78      0.75      1799
#
# Model for code 045100 saved as model_045100.joblib
# Accuracy for code 045100: 0.7645070422535212
# Confusion Matrix for code 045100:
# [[ 136    5  172]
#  [  43   63  134]
#  [  33   31 1158]]
# Classification Report for code 045100:
#               precision    recall  f1-score   support
#
#            0       0.64      0.43      0.52       313
#            1       0.64      0.26      0.37       240
#            2       0.79      0.95      0.86      1222
#
#     accuracy                           0.76      1775
#    macro avg       0.69      0.55      0.58      1775
# weighted avg       0.74      0.76      0.74      1775
#
# Model for code 041830 saved as model_041830.joblib
# Accuracy for code 041830: 0.7525655644241733
# Confusion Matrix for code 041830:
# [[ 138   14  145]
#  [  45   50  161]
#  [  42   27 1132]]
# Classification Report for code 041830:
#               precision    recall  f1-score   support
#
#            0       0.61      0.46      0.53       297
#            1       0.55      0.20      0.29       256
#            2       0.79      0.94      0.86      1201
#
#     accuracy                           0.75      1754
#    macro avg       0.65      0.53      0.56      1754
# weighted avg       0.72      0.75      0.72      1754
#
# Model for code 083450 saved as model_083450.joblib
# Accuracy for code 083450: 0.7854545454545454
# Confusion Matrix for code 083450:
# [[112  20  99]
#  [ 47  49  94]
#  [ 18  17 919]]
# Classification Report for code 083450:
#               precision    recall  f1-score   support
#
#            0       0.63      0.48      0.55       231
#            1       0.57      0.26      0.36       190
#            2       0.83      0.96      0.89       954
#
#     accuracy                           0.79      1375
#    macro avg       0.68      0.57      0.60      1375
# weighted avg       0.76      0.79      0.76      1375
#
# Model for code 018310 saved as model_018310.joblib
# Accuracy for code 018310: 0.7859922178988327
# Confusion Matrix for code 018310:
# [[ 103   13  139]
#  [  49   52  123]
#  [  34   27 1259]]
# Classification Report for code 018310:
#               precision    recall  f1-score   support
#
#            0       0.55      0.40      0.47       255
#            1       0.57      0.23      0.33       224
#            2       0.83      0.95      0.89      1320
#
#     accuracy                           0.79      1799
#    macro avg       0.65      0.53      0.56      1799
# weighted avg       0.76      0.79      0.76      1799
#
# Model for code 267980 saved as model_267980.joblib
# Accuracy for code 267980: 0.7556390977443609
# Confusion Matrix for code 267980:
# [[ 37  16  31]
#  [ 23  48  24]
#  [ 15  21 317]]
# Classification Report for code 267980:
#               precision    recall  f1-score   support
#
#            0       0.49      0.44      0.47        84
#            1       0.56      0.51      0.53        95
#            2       0.85      0.90      0.87       353
#
#     accuracy                           0.76       532
#    macro avg       0.64      0.61      0.62       532
# weighted avg       0.74      0.76      0.75       532
#
# Model for code 060250 saved as model_060250.joblib
# Accuracy for code 060250: 0.791293977340489
# Confusion Matrix for code 060250:
# [[ 153   13  109]
#  [  55   42  118]
#  [  41   14 1132]]
# Classification Report for code 060250:
#               precision    recall  f1-score   support
#
#            0       0.61      0.56      0.58       275
#            1       0.61      0.20      0.30       215
#            2       0.83      0.95      0.89      1187
#
#     accuracy                           0.79      1677
#    macro avg       0.69      0.57      0.59      1677
# weighted avg       0.77      0.79      0.76      1677
#
# Model for code 265520 saved as model_265520.joblib
# Accuracy for code 265520: 0.8139963167587477
# Confusion Matrix for code 265520:
# [[ 55   6  30]
#  [  5  32  41]
#  [  9  10 355]]
# Classification Report for code 265520:
#               precision    recall  f1-score   support
#
#            0       0.80      0.60      0.69        91
#            1       0.67      0.41      0.51        78
#            2       0.83      0.95      0.89       374
#
#     accuracy                           0.81       543
#    macro avg       0.77      0.65      0.69       543
# weighted avg       0.80      0.81      0.80       543
#
# Model for code 126700 saved as model_126700.joblib
# Accuracy for code 126700: 0.7943743937924346
# Confusion Matrix for code 126700:
# [[110  14  53]
#  [ 21  39  74]
#  [ 26  24 670]]
# Classification Report for code 126700:
#               precision    recall  f1-score   support
#
#            0       0.70      0.62      0.66       177
#            1       0.51      0.29      0.37       134
#            2       0.84      0.93      0.88       720
#
#     accuracy                           0.79      1031
#    macro avg       0.68      0.61      0.64      1031
# weighted avg       0.77      0.79      0.78      1031
#
# Model for code 050890 saved as model_050890.joblib
# Accuracy for code 050890: 0.8229901269393513
# Confusion Matrix for code 050890:
# [[137   4  88]
#  [ 19  44  97]
#  [ 23  20 986]]
# Classification Report for code 050890:
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67       229
#            1       0.65      0.28      0.39       160
#            2       0.84      0.96      0.90      1029
#
#     accuracy                           0.82      1418
#    macro avg       0.75      0.61      0.65      1418
# weighted avg       0.81      0.82      0.80      1418
#
# Model for code 035600 saved as model_035600.joblib
# Accuracy for code 035600: 0.8058312655086849
# Confusion Matrix for code 035600:
# [[ 142    8  109]
#  [  37   55  113]
#  [  31   15 1102]]
# Classification Report for code 035600:
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61       259
#            1       0.71      0.27      0.39       205
#            2       0.83      0.96      0.89      1148
#
#     accuracy                           0.81      1612
#    macro avg       0.74      0.59      0.63      1612
# weighted avg       0.79      0.81      0.78      1612
#
# Model for code 051370 saved as model_051370.joblib
# Accuracy for code 051370: 0.8075
# Confusion Matrix for code 051370:
# [[ 163   31   77]
#  [  44   93   86]
#  [  40   30 1036]]
# Classification Report for code 051370:
#               precision    recall  f1-score   support
#
#            0       0.66      0.60      0.63       271
#            1       0.60      0.42      0.49       223
#            2       0.86      0.94      0.90      1106
#
#     accuracy                           0.81      1600
#    macro avg       0.71      0.65      0.67      1600
# weighted avg       0.79      0.81      0.80      1600
#
# Model for code 054950 saved as model_054950.joblib
# Accuracy for code 054950: 0.7983691623424759
# Confusion Matrix for code 054950:
# [[118  12  87]
#  [ 24  68  98]
#  [ 28  23 891]]
# Classification Report for code 054950:
#               precision    recall  f1-score   support
#
#            0       0.69      0.54      0.61       217
#            1       0.66      0.36      0.46       190
#            2       0.83      0.95      0.88       942
#
#     accuracy                           0.80      1349
#    macro avg       0.73      0.62      0.65      1349
# weighted avg       0.78      0.80      0.78      1349
#
# Model for code 299900 saved as model_299900.joblib
# Accuracy for code 299900: 0.8305489260143198
# Confusion Matrix for code 299900:
# [[ 37   6  23]
#  [ 11  13  21]
#  [  6   4 298]]
# Classification Report for code 299900:
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62        66
#            1       0.57      0.29      0.38        45
#            2       0.87      0.97      0.92       308
#
#     accuracy                           0.83       419
#    macro avg       0.71      0.61      0.64       419
# weighted avg       0.81      0.83      0.81       419
#
# Model for code 211050 saved as model_211050.joblib
# Accuracy for code 211050: 0.8080495356037152
# Confusion Matrix for code 211050:
# [[ 34  14  45]
#  [ 18  27  22]
#  [ 18   7 461]]
# Classification Report for code 211050:
#               precision    recall  f1-score   support
#
#            0       0.49      0.37      0.42        93
#            1       0.56      0.40      0.47        67
#            2       0.87      0.95      0.91       486
#
#     accuracy                           0.81       646
#    macro avg       0.64      0.57      0.60       646
# weighted avg       0.79      0.81      0.79       646
#
# Model for code 148150 saved as model_148150.joblib
# Accuracy for code 148150: 0.7700534759358288
# Confusion Matrix for code 148150:
# [[ 22   6  30]
#  [  6  15  29]
#  [  6   9 251]]
# Classification Report for code 148150:
#               precision    recall  f1-score   support
#
#            0       0.65      0.38      0.48        58
#            1       0.50      0.30      0.37        50
#            2       0.81      0.94      0.87       266
#
#     accuracy                           0.77       374
#    macro avg       0.65      0.54      0.57       374
# weighted avg       0.74      0.77      0.74       374
#
# Model for code 118990 saved as model_118990.joblib
# Accuracy for code 118990: 0.8420038535645472
# Confusion Matrix for code 118990:
# [[ 46   9  21]
#  [ 12   8  31]
#  [  3   6 383]]
# Classification Report for code 118990:
#               precision    recall  f1-score   support
#
#            0       0.75      0.61      0.67        76
#            1       0.35      0.16      0.22        51
#            2       0.88      0.98      0.93       392
#
#     accuracy                           0.84       519
#    macro avg       0.66      0.58      0.60       519
# weighted avg       0.81      0.84      0.82       519
#
# Model for code 078150 saved as model_078150.joblib
# Accuracy for code 078150: 0.8008213552361396
# Confusion Matrix for code 078150:
# [[136   7 111]
#  [ 29  60 100]
#  [ 24  20 974]]
# Classification Report for code 078150:
#               precision    recall  f1-score   support
#
#            0       0.72      0.54      0.61       254
#            1       0.69      0.32      0.43       189
#            2       0.82      0.96      0.88      1018
#
#     accuracy                           0.80      1461
#    macro avg       0.74      0.60      0.64      1461
# weighted avg       0.79      0.80      0.78      1461
#
# Model for code 108230 saved as model_108230.joblib
# Accuracy for code 108230: 0.7918552036199095
# Confusion Matrix for code 108230:
# [[ 82   8  85]
#  [ 13  28  95]
#  [ 20   9 765]]
# Classification Report for code 108230:
#               precision    recall  f1-score   support
#
#            0       0.71      0.47      0.57       175
#            1       0.62      0.21      0.31       136
#            2       0.81      0.96      0.88       794
#
#     accuracy                           0.79      1105
#    macro avg       0.71      0.55      0.58      1105
# weighted avg       0.77      0.79      0.76      1105
#
# Model for code 950170 saved as model_950170.joblib
# Accuracy for code 950170: 0.7940552016985138
# Confusion Matrix for code 950170:
# [[ 29   9  29]
#  [ 14  25  31]
#  [  6   8 320]]
# Classification Report for code 950170:
#               precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50        67
#            1       0.60      0.36      0.45        70
#            2       0.84      0.96      0.90       334
#
#     accuracy                           0.79       471
#    macro avg       0.68      0.58      0.61       471
# weighted avg       0.77      0.79      0.77       471
#
# Model for code 054450 saved as model_054450.joblib
# Accuracy for code 054450: 0.7767123287671233
# Confusion Matrix for code 054450:
# [[ 90  20 113]
#  [ 30  51 111]
#  [ 30  22 993]]
# Classification Report for code 054450:
#               precision    recall  f1-score   support
#
#            0       0.60      0.40      0.48       223
#            1       0.55      0.27      0.36       192
#            2       0.82      0.95      0.88      1045
#
#     accuracy                           0.78      1460
#    macro avg       0.65      0.54      0.57      1460
# weighted avg       0.75      0.78      0.75      1460
#
# Model for code 051500 saved as model_051500.joblib
# Accuracy for code 051500: 0.7614035087719299
# Confusion Matrix for code 051500:
# [[ 101   35  144]
#  [  39   92  136]
#  [  31   23 1109]]
# Classification Report for code 051500:
#               precision    recall  f1-score   support
#
#            0       0.59      0.36      0.45       280
#            1       0.61      0.34      0.44       267
#            2       0.80      0.95      0.87      1163
#
#     accuracy                           0.76      1710
#    macro avg       0.67      0.55      0.59      1710
# weighted avg       0.74      0.76      0.73      1710
#
# Model for code 052400 saved as model_052400.joblib
# Accuracy for code 052400: 0.8168930891907856
# Confusion Matrix for code 052400:
# [[ 209   31   84]
#  [  51   82   94]
#  [  28   22 1092]]
# Classification Report for code 052400:
#               precision    recall  f1-score   support
#
#            0       0.73      0.65      0.68       324
#            1       0.61      0.36      0.45       227
#            2       0.86      0.96      0.91      1142
#
#     accuracy                           0.82      1693
#    macro avg       0.73      0.65      0.68      1693
# weighted avg       0.80      0.82      0.80      1693
#
# Model for code 236200 saved as model_236200.joblib
# Accuracy for code 236200: 0.7952380952380952
# Confusion Matrix for code 236200:
# [[ 44   6  47]
#  [ 11  33  42]
#  [  9  14 424]]
# Classification Report for code 236200:
#               precision    recall  f1-score   support
#
#            0       0.69      0.45      0.55        97
#            1       0.62      0.38      0.47        86
#            2       0.83      0.95      0.88       447
#
#     accuracy                           0.80       630
#    macro avg       0.71      0.60      0.63       630
# weighted avg       0.78      0.80      0.78       630
#
# Model for code 083310 saved as model_083310.joblib
# Accuracy for code 083310: 0.7764285714285715
# Confusion Matrix for code 083310:
# [[126   9 108]
#  [ 25  46 117]
#  [ 26  28 915]]
# Classification Report for code 083310:
#               precision    recall  f1-score   support
#
#            0       0.71      0.52      0.60       243
#            1       0.55      0.24      0.34       188
#            2       0.80      0.94      0.87       969
#
#     accuracy                           0.78      1400
#    macro avg       0.69      0.57      0.60      1400
# weighted avg       0.75      0.78      0.75      1400
#
# Model for code 190510 saved as model_190510.joblib
# Accuracy for code 190510: 0.8098918083462133
# Confusion Matrix for code 190510:
# [[ 47  11  38]
#  [ 10  29  41]
#  [  7  16 448]]
# Classification Report for code 190510:
#               precision    recall  f1-score   support
#
#            0       0.73      0.49      0.59        96
#            1       0.52      0.36      0.43        80
#            2       0.85      0.95      0.90       471
#
#     accuracy                           0.81       647
#    macro avg       0.70      0.60      0.64       647
# weighted avg       0.79      0.81      0.79       647
#
# Model for code 194700 saved as model_194700.joblib
# Accuracy for code 194700: 0.8145539906103286
# Confusion Matrix for code 194700:
# [[ 41   6  22]
#  [  9  28  24]
#  [ 10   8 278]]
# Classification Report for code 194700:
#               precision    recall  f1-score   support
#
#            0       0.68      0.59      0.64        69
#            1       0.67      0.46      0.54        61
#            2       0.86      0.94      0.90       296
#
#     accuracy                           0.81       426
#    macro avg       0.74      0.66      0.69       426
# weighted avg       0.80      0.81      0.80       426
#
# Model for code 377450 saved as model_377450.joblib
# Accuracy for code 377450: 0.8461538461538461
# Confusion Matrix for code 377450:
# [[ 10   5  10]
#  [  8  10   4]
#  [  1   4 156]]
# Classification Report for code 377450:
#               precision    recall  f1-score   support
#
#            0       0.53      0.40      0.45        25
#            1       0.53      0.45      0.49        22
#            2       0.92      0.97      0.94       161
#
#     accuracy                           0.85       208
#    macro avg       0.66      0.61      0.63       208
# weighted avg       0.83      0.85      0.84       208
#
# Model for code 023760 saved as model_023760.joblib
# Accuracy for code 023760: 0.7698721511951084
# Confusion Matrix for code 023760:
# [[  77   13  170]
#  [  19   51  163]
#  [  28   21 1257]]
# Classification Report for code 023760:
#               precision    recall  f1-score   support
#
#            0       0.62      0.30      0.40       260
#            1       0.60      0.22      0.32       233
#            2       0.79      0.96      0.87      1306
#
#     accuracy                           0.77      1799
#    macro avg       0.67      0.49      0.53      1799
# weighted avg       0.74      0.77      0.73      1799
#
# Model for code 067280 saved as model_067280.joblib
# Accuracy for code 067280: 0.770516717325228
# Confusion Matrix for code 067280:
# [[ 87  14  93]
#  [ 21  48 120]
#  [ 29  25 879]]
# Classification Report for code 067280:
#               precision    recall  f1-score   support
#
#            0       0.64      0.45      0.53       194
#            1       0.55      0.25      0.35       189
#            2       0.80      0.94      0.87       933
#
#     accuracy                           0.77      1316
#    macro avg       0.66      0.55      0.58      1316
# weighted avg       0.74      0.77      0.74      1316
#
# Model for code 046440 saved as model_046440.joblib
# Accuracy for code 046440: 0.7972602739726027
# Confusion Matrix for code 046440:
# [[ 108    9  112]
#  [  25   39  111]
#  [  20   19 1017]]
# Classification Report for code 046440:
#               precision    recall  f1-score   support
#
#            0       0.71      0.47      0.57       229
#            1       0.58      0.22      0.32       175
#            2       0.82      0.96      0.89      1056
#
#     accuracy                           0.80      1460
#    macro avg       0.70      0.55      0.59      1460
# weighted avg       0.77      0.80      0.77      1460
#
# Model for code 092730 saved as model_092730.joblib
# Accuracy for code 092730: 0.7724827056110684
# Confusion Matrix for code 092730:
# [[106  15  88]
#  [ 26  44 121]
#  [ 20  26 855]]
# Classification Report for code 092730:
#               precision    recall  f1-score   support
#
#            0       0.70      0.51      0.59       209
#            1       0.52      0.23      0.32       191
#            2       0.80      0.95      0.87       901
#
#     accuracy                           0.77      1301
#    macro avg       0.67      0.56      0.59      1301
# weighted avg       0.74      0.77      0.74      1301
#
# Model for code 136540 saved as model_136540.joblib
# Accuracy for code 136540: 0.7568667344862665
# Confusion Matrix for code 136540:
# [[ 59   8  93]
#  [ 15  39  85]
#  [ 20  18 646]]
# Classification Report for code 136540:
#               precision    recall  f1-score   support
#
#            0       0.63      0.37      0.46       160
#            1       0.60      0.28      0.38       139
#            2       0.78      0.94      0.86       684
#
#     accuracy                           0.76       983
#    macro avg       0.67      0.53      0.57       983
# weighted avg       0.73      0.76      0.73       983
#
# Model for code 123410 saved as model_123410.joblib
# Accuracy for code 123410: 0.8056092843326886
# Confusion Matrix for code 123410:
# [[ 69  12  76]
#  [ 13  21  83]
#  [ 10   7 743]]
# Classification Report for code 123410:
#               precision    recall  f1-score   support
#
#            0       0.75      0.44      0.55       157
#            1       0.53      0.18      0.27       117
#            2       0.82      0.98      0.89       760
#
#     accuracy                           0.81      1034
#    macro avg       0.70      0.53      0.57      1034
# weighted avg       0.78      0.81      0.77      1034
#
# Model for code 214180 saved as model_214180.joblib
# Accuracy for code 214180: 0.7985185185185185
# Confusion Matrix for code 214180:
# [[ 64   7  43]
#  [ 13  45  45]
#  [ 11  17 430]]
# Classification Report for code 214180:
#               precision    recall  f1-score   support
#
#            0       0.73      0.56      0.63       114
#            1       0.65      0.44      0.52       103
#            2       0.83      0.94      0.88       458
#
#     accuracy                           0.80       675
#    macro avg       0.74      0.65      0.68       675
# weighted avg       0.79      0.80      0.78       675
#
# Model for code 036190 saved as model_036190.joblib
# Accuracy for code 036190: 0.771689497716895
# Confusion Matrix for code 036190:
# [[ 120   43  112]
#  [  59   61  109]
#  [  48   29 1171]]
# Classification Report for code 036190:
#               precision    recall  f1-score   support
#
#            0       0.53      0.44      0.48       275
#            1       0.46      0.27      0.34       229
#            2       0.84      0.94      0.89      1248
#
#     accuracy                           0.77      1752
#    macro avg       0.61      0.55      0.57      1752
# weighted avg       0.74      0.77      0.75      1752
#
# Model for code 023910 saved as model_023910.joblib
# Accuracy for code 023910: 0.7720956086714842
# Confusion Matrix for code 023910:
# [[ 105   23  138]
#  [  38   77  141]
#  [  35   35 1207]]
# Classification Report for code 023910:
#               precision    recall  f1-score   support
#
#            0       0.59      0.39      0.47       266
#            1       0.57      0.30      0.39       256
#            2       0.81      0.95      0.87      1277
#
#     accuracy                           0.77      1799
#    macro avg       0.66      0.55      0.58      1799
# weighted avg       0.74      0.77      0.75      1799
#
# Model for code 091580 saved as model_091580.joblib
# Accuracy for code 091580: 0.8035993740219093
# Confusion Matrix for code 091580:
# [[109   9  85]
#  [ 32  49  84]
#  [ 21  20 869]]
# Classification Report for code 091580:
#               precision    recall  f1-score   support
#
#            0       0.67      0.54      0.60       203
#            1       0.63      0.30      0.40       165
#            2       0.84      0.95      0.89       910
#
#     accuracy                           0.80      1278
#    macro avg       0.71      0.60      0.63      1278
# weighted avg       0.78      0.80      0.78      1278
#
# Model for code 298540 saved as model_298540.joblib
# Accuracy for code 298540: 0.7973421926910299
# Confusion Matrix for code 298540:
# [[ 30  11   9]
#  [ 10  21  14]
#  [  2  15 189]]
# Classification Report for code 298540:
#               precision    recall  f1-score   support
#
#            0       0.71      0.60      0.65        50
#            1       0.45      0.47      0.46        45
#            2       0.89      0.92      0.90       206
#
#     accuracy                           0.80       301
#    macro avg       0.68      0.66      0.67       301
# weighted avg       0.80      0.80      0.80       301
#
# Model for code 079960 saved as model_079960.joblib
# Accuracy for code 079960: 0.7674258109040718
# Confusion Matrix for code 079960:
# [[104  11 102]
#  [ 25  67 125]
#  [ 34  40 941]]
# Classification Report for code 079960:
#               precision    recall  f1-score   support
#
#            0       0.64      0.48      0.55       217
#            1       0.57      0.31      0.40       217
#            2       0.81      0.93      0.86      1015
#
#     accuracy                           0.77      1449
#    macro avg       0.67      0.57      0.60      1449
# weighted avg       0.74      0.77      0.75      1449
#
# Model for code 009300 saved as model_009300.joblib
# Accuracy for code 009300: 0.773542600896861
# Confusion Matrix for code 009300:
# [[  82   12  152]
#  [  23   53  168]
#  [  28   21 1245]]
# Classification Report for code 009300:
#               precision    recall  f1-score   support
#
#            0       0.62      0.33      0.43       246
#            1       0.62      0.22      0.32       244
#            2       0.80      0.96      0.87      1294
#
#     accuracy                           0.77      1784
#    macro avg       0.68      0.50      0.54      1784
# weighted avg       0.75      0.77      0.74      1784
#
# Model for code 418470 saved as model_418470.joblib
# Accuracy for code 418470: 0.8
# Confusion Matrix for code 418470:
# [[ 6  1  4]
#  [ 2  5  3]
#  [ 2  1 41]]
# Classification Report for code 418470:
#               precision    recall  f1-score   support
#
#            0       0.60      0.55      0.57        11
#            1       0.71      0.50      0.59        10
#            2       0.85      0.93      0.89        44
#
#     accuracy                           0.80        65
#    macro avg       0.72      0.66      0.68        65
# weighted avg       0.79      0.80      0.79        65
#
# Model for code 023600 saved as model_023600.joblib
# Accuracy for code 023600: 0.7821011673151751
# Confusion Matrix for code 023600:
# [[  96   13  146]
#  [  43   61  142]
#  [  28   20 1250]]
# Classification Report for code 023600:
#               precision    recall  f1-score   support
#
#            0       0.57      0.38      0.45       255
#            1       0.65      0.25      0.36       246
#            2       0.81      0.96      0.88      1298
#
#     accuracy                           0.78      1799
#    macro avg       0.68      0.53      0.57      1799
# weighted avg       0.76      0.78      0.75      1799
#
# Model for code 452400 saved as model_452400.joblib
# Accuracy for code 452400: 0.925
# Confusion Matrix for code 452400:
# [[ 3  0  1]
#  [ 1  2  1]
#  [ 0  0 32]]
# Classification Report for code 452400:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       1.00      0.50      0.67         4
#            2       0.94      1.00      0.97        32
#
#     accuracy                           0.93        40
#    macro avg       0.90      0.75      0.80        40
# weighted avg       0.93      0.93      0.92        40
#
# Model for code 950190 saved as model_950190.joblib
# Accuracy for code 950190: 0.8581081081081081
# Confusion Matrix for code 950190:
# [[ 23   8   5]
#  [  7  16  13]
#  [  2   7 215]]
# Classification Report for code 950190:
#               precision    recall  f1-score   support
#
#            0       0.72      0.64      0.68        36
#            1       0.52      0.44      0.48        36
#            2       0.92      0.96      0.94       224
#
#     accuracy                           0.86       296
#    macro avg       0.72      0.68      0.70       296
# weighted avg       0.85      0.86      0.85       296
#
# Model for code 203650 saved as model_203650.joblib
# Accuracy for code 203650: 0.8489010989010989
# Confusion Matrix for code 203650:
# [[ 58   5  43]
#  [  7  12  44]
#  [  8   3 548]]
# Classification Report for code 203650:
#               precision    recall  f1-score   support
#
#            0       0.79      0.55      0.65       106
#            1       0.60      0.19      0.29        63
#            2       0.86      0.98      0.92       559
#
#     accuracy                           0.85       728
#    macro avg       0.75      0.57      0.62       728
# weighted avg       0.83      0.85      0.82       728
#
# Model for code 259630 saved as model_259630.joblib
# Accuracy for code 259630: 0.8098039215686275
# Confusion Matrix for code 259630:
# [[ 47   8  29]
#  [  4  29  32]
#  [ 18   6 337]]
# Classification Report for code 259630:
#               precision    recall  f1-score   support
#
#            0       0.68      0.56      0.61        84
#            1       0.67      0.45      0.54        65
#            2       0.85      0.93      0.89       361
#
#     accuracy                           0.81       510
#    macro avg       0.73      0.65      0.68       510
# weighted avg       0.80      0.81      0.80       510
#
# Model for code 285490 saved as model_285490.joblib
# Accuracy for code 285490: 0.8321678321678322
# Confusion Matrix for code 285490:
# [[ 37  13  10]
#  [ 13  18  23]
#  [  8   5 302]]
# Classification Report for code 285490:
#               precision    recall  f1-score   support
#
#            0       0.64      0.62      0.63        60
#            1       0.50      0.33      0.40        54
#            2       0.90      0.96      0.93       315
#
#     accuracy                           0.83       429
#    macro avg       0.68      0.64      0.65       429
# weighted avg       0.81      0.83      0.82       429
#
# Model for code 445180 saved as model_445180.joblib
# Accuracy for code 445180: 0.8709677419354839
# Confusion Matrix for code 445180:
# [[ 6  0  3]
#  [ 0  1  3]
#  [ 2  0 47]]
# Classification Report for code 445180:
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       1.00      0.25      0.40         4
#            2       0.89      0.96      0.92        49
#
#     accuracy                           0.87        62
#    macro avg       0.88      0.63      0.68        62
# weighted avg       0.87      0.87      0.86        62
#
# Model for code 038110 saved as model_038110.joblib
# Accuracy for code 038110: 0.7971095052807116
# Confusion Matrix for code 038110:
# [[ 103    7  149]
#  [  29   30  136]
#  [  28   16 1301]]
# Classification Report for code 038110:
#               precision    recall  f1-score   support
#
#            0       0.64      0.40      0.49       259
#            1       0.57      0.15      0.24       195
#            2       0.82      0.97      0.89      1345
#
#     accuracy                           0.80      1799
#    macro avg       0.68      0.51      0.54      1799
# weighted avg       0.77      0.80      0.76      1799
#
# Model for code 264450 saved as model_264450.joblib
# Accuracy for code 264450: 0.7889908256880734
# Confusion Matrix for code 264450:
# [[ 52   7  28]
#  [ 13  27  43]
#  [ 12  12 351]]
# Classification Report for code 264450:
#               precision    recall  f1-score   support
#
#            0       0.68      0.60      0.63        87
#            1       0.59      0.33      0.42        83
#            2       0.83      0.94      0.88       375
#
#     accuracy                           0.79       545
#    macro avg       0.70      0.62      0.64       545
# weighted avg       0.77      0.79      0.77       545
#
# Model for code 033290 saved as model_033290.joblib
# Accuracy for code 033290: 0.7893274041133963
# Confusion Matrix for code 033290:
# [[ 141   12  134]
#  [  44   58  142]
#  [  26   21 1221]]
# Classification Report for code 033290:
#               precision    recall  f1-score   support
#
#            0       0.67      0.49      0.57       287
#            1       0.64      0.24      0.35       244
#            2       0.82      0.96      0.88      1268
#
#     accuracy                           0.79      1799
#    macro avg       0.71      0.56      0.60      1799
# weighted avg       0.77      0.79      0.76      1799
#
# Model for code 099440 saved as model_099440.joblib
# Accuracy for code 099440: 0.8325952170062002
# Confusion Matrix for code 099440:
# [[ 69  12  74]
#  [ 11  32  66]
#  [ 17   9 839]]
# Classification Report for code 099440:
#               precision    recall  f1-score   support
#
#            0       0.71      0.45      0.55       155
#            1       0.60      0.29      0.40       109
#            2       0.86      0.97      0.91       865
#
#     accuracy                           0.83      1129
#    macro avg       0.72      0.57      0.62      1129
# weighted avg       0.81      0.83      0.81      1129
#
# Model for code 060560 saved as model_060560.joblib
# Accuracy for code 060560: 0.7969512195121952
# Confusion Matrix for code 060560:
# [[  89   14  128]
#  [  11   40  127]
#  [  36   17 1178]]
# Classification Report for code 060560:
#               precision    recall  f1-score   support
#
#            0       0.65      0.39      0.49       231
#            1       0.56      0.22      0.32       178
#            2       0.82      0.96      0.88      1231
#
#     accuracy                           0.80      1640
#    macro avg       0.68      0.52      0.56      1640
# weighted avg       0.77      0.80      0.77      1640
#
# Model for code 353810 saved as model_353810.joblib
# Accuracy for code 353810: 0.8205128205128205
# Confusion Matrix for code 353810:
# [[ 24   1  15]
#  [  9   5  14]
#  [ 10   7 227]]
# Classification Report for code 353810:
#               precision    recall  f1-score   support
#
#            0       0.56      0.60      0.58        40
#            1       0.38      0.18      0.24        28
#            2       0.89      0.93      0.91       244
#
#     accuracy                           0.82       312
#    macro avg       0.61      0.57      0.58       312
# weighted avg       0.80      0.82      0.81       312
#
# Model for code 092460 saved as model_092460.joblib
# Accuracy for code 092460: 0.7965571205007824
# Confusion Matrix for code 092460:
# [[ 81   4  95]
#  [ 12  37 110]
#  [ 24  15 900]]
# Classification Report for code 092460:
#               precision    recall  f1-score   support
#
#            0       0.69      0.45      0.55       180
#            1       0.66      0.23      0.34       159
#            2       0.81      0.96      0.88       939
#
#     accuracy                           0.80      1278
#    macro avg       0.72      0.55      0.59      1278
# weighted avg       0.78      0.80      0.77      1278
#
# Model for code 066620 saved as model_066620.joblib
# Accuracy for code 066620: 0.7708845208845209
# Confusion Matrix for code 066620:
# [[ 110   21  135]
#  [  29   49  129]
#  [  34   25 1096]]
# Classification Report for code 066620:
#               precision    recall  f1-score   support
#
#            0       0.64      0.41      0.50       266
#            1       0.52      0.24      0.32       207
#            2       0.81      0.95      0.87      1155
#
#     accuracy                           0.77      1628
#    macro avg       0.65      0.53      0.57      1628
# weighted avg       0.74      0.77      0.74      1628
#
# Model for code 100700 saved as model_100700.joblib
# Accuracy for code 100700: 0.7860780984719864
# Confusion Matrix for code 100700:
# [[ 82   6  91]
#  [ 14  11  97]
#  [ 32  12 833]]
# Classification Report for code 100700:
#               precision    recall  f1-score   support
#
#            0       0.64      0.46      0.53       179
#            1       0.38      0.09      0.15       122
#            2       0.82      0.95      0.88       877
#
#     accuracy                           0.79      1178
#    macro avg       0.61      0.50      0.52      1178
# weighted avg       0.74      0.79      0.75      1178
#
# Model for code 382800 saved as model_382800.joblib
# Accuracy for code 382800: 0.7932692307692307
# Confusion Matrix for code 382800:
# [[ 17   4  11]
#  [  7   6  13]
#  [  3   5 142]]
# Classification Report for code 382800:
#               precision    recall  f1-score   support
#
#            0       0.63      0.53      0.58        32
#            1       0.40      0.23      0.29        26
#            2       0.86      0.95      0.90       150
#
#     accuracy                           0.79       208
#    macro avg       0.63      0.57      0.59       208
# weighted avg       0.76      0.79      0.77       208
#
# Model for code 067900 saved as model_067900.joblib
# Accuracy for code 067900: 0.8083875632682574
# Confusion Matrix for code 067900:
# [[106  10  82]
#  [ 23  37 112]
#  [ 26  12 975]]
# Classification Report for code 067900:
#               precision    recall  f1-score   support
#
#            0       0.68      0.54      0.60       198
#            1       0.63      0.22      0.32       172
#            2       0.83      0.96      0.89      1013
#
#     accuracy                           0.81      1383
#    macro avg       0.72      0.57      0.60      1383
# weighted avg       0.79      0.81      0.78      1383
#
# Model for code 066700 saved as model_066700.joblib
# Accuracy for code 066700: 0.7929427430093209
# Confusion Matrix for code 066700:
# [[ 101    9  117]
#  [  25   50  115]
#  [  26   19 1040]]
# Classification Report for code 066700:
#               precision    recall  f1-score   support
#
#            0       0.66      0.44      0.53       227
#            1       0.64      0.26      0.37       190
#            2       0.82      0.96      0.88      1085
#
#     accuracy                           0.79      1502
#    macro avg       0.71      0.56      0.60      1502
# weighted avg       0.77      0.79      0.77      1502
#
# Model for code 069510 saved as model_069510.joblib
# ...
#  [ 14   9  61]
#  [ 15   5 739]]
# Classification Report for code 019770:
#               precision    recall  f1-score   support
#
#            0       0.70      0.52      0.60       129
#            1       0.60      0.11      0.18        84
#            2       0.86      0.97      0.91       759
#
#     accuracy                           0.84       972
#    macro avg       0.72      0.53      0.56       972
# weighted avg       0.81      0.84      0.81       972
#
# Model for code 332370 saved as model_332370.joblib
# Accuracy for code 332370: 0.8406779661016949
# Confusion Matrix for code 332370:
# [[ 11   3  17]
#  [  7  11  17]
#  [  1   2 226]]
# Classification Report for code 332370:
#               precision    recall  f1-score   support
#
#            0       0.58      0.35      0.44        31
#            1       0.69      0.31      0.43        35
#            2       0.87      0.99      0.92       229
#
#     accuracy                           0.84       295
#    macro avg       0.71      0.55      0.60       295
# weighted avg       0.82      0.84      0.81       295
#
# Model for code 246690 saved as model_246690.joblib
# Accuracy for code 246690: 0.8498233215547704
# Confusion Matrix for code 246690:
# [[ 34   5  28]
#  [  9   9  26]
#  [ 14   3 438]]
# Classification Report for code 246690:
#               precision    recall  f1-score   support
#
#            0       0.60      0.51      0.55        67
#            1       0.53      0.20      0.30        44
#            2       0.89      0.96      0.93       455
#
#     accuracy                           0.85       566
#    macro avg       0.67      0.56      0.59       566
# weighted avg       0.83      0.85      0.83       566
#
# Model for code 111870 saved as model_111870.joblib
# Accuracy for code 111870: 0.8372549019607843
# Confusion Matrix for code 111870:
# [[169  10  53]
#  [ 12  29  59]
#  [ 20  12 656]]
# Classification Report for code 111870:
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78       232
#            1       0.57      0.29      0.38       100
#            2       0.85      0.95      0.90       688
#
#     accuracy                           0.84      1020
#    macro avg       0.75      0.66      0.69      1020
# weighted avg       0.82      0.84      0.82      1020
#
# Model for code 066360 saved as model_066360.joblib
# Accuracy for code 066360: 0.8363636363636363
# Confusion Matrix for code 066360:
# [[ 25  14  18]
#  [  6  15  27]
#  [ 11   5 374]]
# Classification Report for code 066360:
#               precision    recall  f1-score   support
#
#            0       0.60      0.44      0.51        57
#            1       0.44      0.31      0.37        48
#            2       0.89      0.96      0.92       390
#
#     accuracy                           0.84       495
#    macro avg       0.64      0.57      0.60       495
# weighted avg       0.81      0.84      0.82       495
#
# Model for code 046310 saved as model_046310.joblib
# Accuracy for code 046310: 0.8096947935368043
# Confusion Matrix for code 046310:
# [[ 104    7  125]
#  [  24   44  126]
#  [  20   16 1205]]
# Classification Report for code 046310:
#               precision    recall  f1-score   support
#
#            0       0.70      0.44      0.54       236
#            1       0.66      0.23      0.34       194
#            2       0.83      0.97      0.89      1241
#
#     accuracy                           0.81      1671
#    macro avg       0.73      0.55      0.59      1671
# weighted avg       0.79      0.81      0.78      1671
#
# Model for code 025880 saved as model_025880.joblib
# Accuracy for code 025880: 0.7998888271261813
# Confusion Matrix for code 025880:
# [[ 102    6  139]
#  [  22   38  141]
#  [  30   22 1299]]
# Classification Report for code 025880:
#               precision    recall  f1-score   support
#
#            0       0.66      0.41      0.51       247
#            1       0.58      0.19      0.28       201
#            2       0.82      0.96      0.89      1351
#
#     accuracy                           0.80      1799
#    macro avg       0.69      0.52      0.56      1799
# weighted avg       0.77      0.80      0.77      1799
#
# Model for code 078590 saved as model_078590.joblib
# Accuracy for code 078590: 0.8487455197132616
# Confusion Matrix for code 078590:
# [[305   9  67]
#  [ 14  36  86]
#  [ 27   8 843]]
# Classification Report for code 078590:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       381
#            1       0.68      0.26      0.38       136
#            2       0.85      0.96      0.90       878
#
#     accuracy                           0.85      1395
#    macro avg       0.80      0.68      0.71      1395
# weighted avg       0.84      0.85      0.83      1395
#
# Model for code 340440 saved as model_340440.joblib
# Accuracy for code 340440: 0.8430232558139535
# Confusion Matrix for code 340440:
# [[ 39   6  17]
#  [  3  15  14]
#  [  9   5 236]]
# Classification Report for code 340440:
#               precision    recall  f1-score   support
#
#            0       0.76      0.63      0.69        62
#            1       0.58      0.47      0.52        32
#            2       0.88      0.94      0.91       250
#
#     accuracy                           0.84       344
#    macro avg       0.74      0.68      0.71       344
# weighted avg       0.83      0.84      0.84       344
#
# Model for code 131090 saved as model_131090.joblib
# Accuracy for code 131090: 0.8032085561497326
# Confusion Matrix for code 131090:
# [[ 65  11  67]
#  [ 10  28  70]
#  [ 15  11 658]]
# Classification Report for code 131090:
#               precision    recall  f1-score   support
#
#            0       0.72      0.45      0.56       143
#            1       0.56      0.26      0.35       108
#            2       0.83      0.96      0.89       684
#
#     accuracy                           0.80       935
#    macro avg       0.70      0.56      0.60       935
# weighted avg       0.78      0.80      0.78       935
#
# Model for code 267790 saved as model_267790.joblib
# Accuracy for code 267790: 0.8095238095238095
# Confusion Matrix for code 267790:
# [[ 40   7  22]
#  [  6  28  29]
#  [ 15  13 323]]
# Classification Report for code 267790:
#               precision    recall  f1-score   support
#
#            0       0.66      0.58      0.62        69
#            1       0.58      0.44      0.50        63
#            2       0.86      0.92      0.89       351
#
#     accuracy                           0.81       483
#    macro avg       0.70      0.65      0.67       483
# weighted avg       0.80      0.81      0.80       483
#
# Model for code 099410 saved as model_099410.joblib
# Accuracy for code 099410: 0.8308957952468007
# Confusion Matrix for code 099410:
# [[ 99   5  64]
#  [ 15  28  80]
#  [ 19   2 782]]
# Classification Report for code 099410:
#               precision    recall  f1-score   support
#
#            0       0.74      0.59      0.66       168
#            1       0.80      0.23      0.35       123
#            2       0.84      0.97      0.90       803
#
#     accuracy                           0.83      1094
#    macro avg       0.80      0.60      0.64      1094
# weighted avg       0.82      0.83      0.80      1094
#
# Model for code 290270 saved as model_290270.joblib
# Accuracy for code 290270: 0.8478747203579419
# Confusion Matrix for code 290270:
# [[ 19   2  23]
#  [  4   5  25]
#  [  8   6 355]]
# Classification Report for code 290270:
#               precision    recall  f1-score   support
#
#            0       0.61      0.43      0.51        44
#            1       0.38      0.15      0.21        34
#            2       0.88      0.96      0.92       369
#
#     accuracy                           0.85       447
#    macro avg       0.63      0.51      0.55       447
# weighted avg       0.82      0.85      0.83       447
#
# Model for code 052460 saved as model_052460.joblib
# Accuracy for code 052460: 0.8317307692307693
# Confusion Matrix for code 052460:
# [[  87   12   81]
#  [  13   48  106]
#  [  17   16 1076]]
# Classification Report for code 052460:
#               precision    recall  f1-score   support
#
#            0       0.74      0.48      0.59       180
#            1       0.63      0.29      0.40       167
#            2       0.85      0.97      0.91      1109
#
#     accuracy                           0.83      1456
#    macro avg       0.74      0.58      0.63      1456
# weighted avg       0.81      0.83      0.81      1456
#
# Model for code 020180 saved as model_020180.joblib
# Accuracy for code 020180: 0.8143413007226237
# Confusion Matrix for code 020180:
# [[ 147   11  115]
#  [  35   40  124]
#  [  34   15 1278]]
# Classification Report for code 020180:
#               precision    recall  f1-score   support
#
#            0       0.68      0.54      0.60       273
#            1       0.61      0.20      0.30       199
#            2       0.84      0.96      0.90      1327
#
#     accuracy                           0.81      1799
#    macro avg       0.71      0.57      0.60      1799
# weighted avg       0.79      0.81      0.79      1799
#
# Model for code 297570 saved as model_297570.joblib
# Accuracy for code 297570: 0.8644444444444445
# Confusion Matrix for code 297570:
# [[ 40   4  12]
#  [  6   7  17]
#  [ 15   7 342]]
# Classification Report for code 297570:
#               precision    recall  f1-score   support
#
#            0       0.66      0.71      0.68        56
#            1       0.39      0.23      0.29        30
#            2       0.92      0.94      0.93       364
#
#     accuracy                           0.86       450
#    macro avg       0.66      0.63      0.64       450
# weighted avg       0.85      0.86      0.86       450
#
# Model for code 362990 saved as model_362990.joblib
# Accuracy for code 362990: 0.9047619047619048
# Confusion Matrix for code 362990:
# [[ 1  1  0]
#  [ 1  0  2]
#  [ 0  0 37]]
# Classification Report for code 362990:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.00      0.00      0.00         3
#            2       0.95      1.00      0.97        37
#
#     accuracy                           0.90        42
#    macro avg       0.48      0.50      0.49        42
# weighted avg       0.86      0.90      0.88        42
#
# Model for code 006920 saved as model_006920.joblib
# Accuracy for code 006920: 0.8287937743190662
# Confusion Matrix for code 006920:
# [[ 158   13   86]
#  [  37   60  104]
#  [  37   31 1273]]
# Classification Report for code 006920:
#               precision    recall  f1-score   support
#
#            0       0.68      0.61      0.65       257
#            1       0.58      0.30      0.39       201
#            2       0.87      0.95      0.91      1341
#
#     accuracy                           0.83      1799
#    macro avg       0.71      0.62      0.65      1799
# weighted avg       0.81      0.83      0.81      1799
#
# Model for code 080470 saved as model_080470.joblib
# Accuracy for code 080470: 0.8104624715693708
# Confusion Matrix for code 080470:
# [[ 74   9  93]
#  [ 17  41  91]
#  [ 21  19 954]]
# Classification Report for code 080470:
#               precision    recall  f1-score   support
#
#            0       0.66      0.42      0.51       176
#            1       0.59      0.28      0.38       149
#            2       0.84      0.96      0.89       994
#
#     accuracy                           0.81      1319
#    macro avg       0.70      0.55      0.59      1319
# weighted avg       0.79      0.81      0.79      1319
#
# Model for code 039310 saved as model_039310.joblib
# Accuracy for code 039310: 0.77734375
# Confusion Matrix for code 039310:
# [[ 117   10  144]
#  [  50   52  136]
#  [  32   27 1224]]
# Classification Report for code 039310:
#               precision    recall  f1-score   support
#
#            0       0.59      0.43      0.50       271
#            1       0.58      0.22      0.32       238
#            2       0.81      0.95      0.88      1283
#
#     accuracy                           0.78      1792
#    macro avg       0.66      0.53      0.56      1792
# weighted avg       0.75      0.78      0.75      1792
#
# Model for code 042940 saved as model_042940.joblib
# Accuracy for code 042940: 0.8023782559456398
# Confusion Matrix for code 042940:
# [[ 123   17  131]
#  [  46   47  118]
#  [  24   13 1247]]
# Classification Report for code 042940:
#               precision    recall  f1-score   support
#
#            0       0.64      0.45      0.53       271
#            1       0.61      0.22      0.33       211
#            2       0.83      0.97      0.90      1284
#
#     accuracy                           0.80      1766
#    macro avg       0.69      0.55      0.58      1766
# weighted avg       0.78      0.80      0.77      1766
#
# Model for code 113810 saved as model_113810.joblib
# Accuracy for code 113810: 0.836027713625866
# Confusion Matrix for code 113810:
# [[ 57   7  44]
#  [ 20  17  45]
#  [ 17   9 650]]
# Classification Report for code 113810:
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.56       108
#            1       0.52      0.21      0.30        82
#            2       0.88      0.96      0.92       676
#
#     accuracy                           0.84       866
#    macro avg       0.67      0.57      0.59       866
# weighted avg       0.81      0.84      0.82       866
#
# Model for code 154040 saved as model_154040.joblib
# Accuracy for code 154040: 0.8445859872611465
# Confusion Matrix for code 154040:
# [[ 44  11  37]
#  [ 15  25  43]
#  [  9   7 594]]
# Classification Report for code 154040:
#               precision    recall  f1-score   support
#
#            0       0.65      0.48      0.55        92
#            1       0.58      0.30      0.40        83
#            2       0.88      0.97      0.93       610
#
#     accuracy                           0.84       785
#    macro avg       0.70      0.58      0.62       785
# weighted avg       0.82      0.84      0.83       785
#
# Model for code 208350 saved as model_208350.joblib
# Accuracy for code 208350: 0.8469101123595506
# Confusion Matrix for code 208350:
# [[ 48   6  39]
#  [  6  13  40]
#  [ 10   8 542]]
# Classification Report for code 208350:
#               precision    recall  f1-score   support
#
#            0       0.75      0.52      0.61        93
#            1       0.48      0.22      0.30        59
#            2       0.87      0.97      0.92       560
#
#     accuracy                           0.85       712
#    macro avg       0.70      0.57      0.61       712
# weighted avg       0.82      0.85      0.83       712
#
# Model for code 043590 saved as model_043590.joblib
# Accuracy for code 043590: 0.8380952380952381
# Confusion Matrix for code 043590:
# [[367   6  84]
#  [ 31  53  99]
#  [ 30  22 988]]
# Classification Report for code 043590:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       457
#            1       0.65      0.29      0.40       183
#            2       0.84      0.95      0.89      1040
#
#     accuracy                           0.84      1680
#    macro avg       0.79      0.68      0.71      1680
# weighted avg       0.83      0.84      0.82      1680
#
# Model for code 053060 saved as model_053060.joblib
# Accuracy for code 053060: 0.8017595307917889
# Confusion Matrix for code 053060:
# [[  94   12  128]
#  [  17   48  125]
#  [  38   18 1225]]
# Classification Report for code 053060:
#               precision    recall  f1-score   support
#
#            0       0.63      0.40      0.49       234
#            1       0.62      0.25      0.36       190
#            2       0.83      0.96      0.89      1281
#
#     accuracy                           0.80      1705
#    macro avg       0.69      0.54      0.58      1705
# weighted avg       0.78      0.80      0.77      1705
#
# Model for code 335870 saved as model_335870.joblib
# Accuracy for code 335870: 0.8045977011494253
# Confusion Matrix for code 335870:
# [[ 53   8  17]
#  [  5  10  21]
#  [ 12   5 217]]
# Classification Report for code 335870:
#               precision    recall  f1-score   support
#
#            0       0.76      0.68      0.72        78
#            1       0.43      0.28      0.34        36
#            2       0.85      0.93      0.89       234
#
#     accuracy                           0.80       348
#    macro avg       0.68      0.63      0.65       348
# weighted avg       0.79      0.80      0.79       348

# %% [markdown]
# ### 코스닥 기업 예측

# %%
035890

# %%
df = fdr.DataReader('035890')
df.tail()
# Out:
#             Open  High   Low  Close   Volume    Change
# Date
# 2024-08-19  1380  1380  1364   1368   329416 -0.006536
# 2024-08-20  1390  1407  1379   1405   738954  0.027047
# 2024-08-21  1411  1459  1409   1458  1237833  0.037722
# 2024-08-22  1448  1459  1405   1406   640682 -0.035665
# 2024-08-23  1415  1433  1415   1431    72332  0.017781

# %%
import joblib
import numpy as np
import pandas as pd
import FinanceDataReader as fdr
from collections import defaultdict

def load_model_and_predict(company_code, recent_data):
    # 기업 코드에 맞는 모델 파일명
    model_filename = f'model_{company_code}.joblib'
    
    try:
        # 모델 불러오기
        model = joblib.load(model_filename)
        
        # 예측 수행
        predicted_signal = model.predict(recent_data)
        
        # 예측 결과 해석
        signal_map = {0: 'Sell', 1: 'Buy', 2: 'No Signal'}
        return predicted_signal[0], signal_map[predicted_signal[0]]
    
    except FileNotFoundError:
        return None, f"Model file for code {company_code} not found."
    except Exception as e:
        return None, f"Error during prediction: {e}"

def display_stock_codes(codes):
    print("Available Stock Codes:")
    for i, code in enumerate(codes):
        if i > 0 and i % 10 == 0:
            print()  # 줄바꿈
        print(code, end=' ')
    print()  # 마지막 줄바꿈

def main():
    # CSV 파일에서 주식 코드 목록 불러오기
    kosdak = pd.read_csv('KOSDAQ_result.csv')
    
    # 주식 코드 목록 선택
    stock_codes = kosdak['Code'].astype(str).str.zfill(6).tolist()
    
    # 코스닥 주식 코드 목록 출력
    display_stock_codes(stock_codes)
    
    # 각 시그널의 개수를 저장할 딕셔너리
    signal_counts = defaultdict(int)
    
    # 모든 주식 코드에 대해 예측 수행
    for company_code in stock_codes:
        # 가장 최근 하루치 데이터 가져오기
        df = fdr.DataReader(company_code).dropna()
        recent_data = df.iloc[-1][['Open', 'High', 'Low', 'Close', 'Volume']].values.reshape(1, -1) # , 'Change'
        
        # 예측 수행
        signal, result = load_model_and_predict(company_code, recent_data)
        
        if signal is not None:
            signal_counts[signal] += 1
            print(f'For company code {company_code}, the predicted signal for the next day is: {result}')
        else:
            print(f'Error for company code {company_code}: {result}')
    
    # 각 시그널의 개수 출력
    print("\nSignal Counts Summary:")
    print(f"Sell (0): {signal_counts[0]}")
    print(f"Buy (1): {signal_counts[1]}")
    print(f"No Signal (2): {signal_counts[2]}")

if __name__ == "__main__":
    main()
# Out:
# Available Stock Codes:
# 041190 015750 215200 025980 095660 215000 290650 099320 006730 101160
# 023160 013030 043150 243070 297890 230360 035890 045100 041830 083450
# 018310 267980 060250 265520 126700 050890 035600 051370 054950 299900
# 211050 148150 118990 078150 108230 950170 054450 051500 052400 236200
# 083310 190510 194700 377450 023760 067280 046440 092730 136540 123410
# 214180 036190 023910 091580 298540 079960 009300 418470 023600 452400
# 950190 203650 259630 285490 445180 038110 264450 033290 099440 060560
# 353810 092460 066620 100700 382800 067900 066700 069510 013310 124560
# 137950 332570 021080 215360 066590 005990 058630 071200 053700 035610
# 011560 089850 142210 352090 036630 019590 042500 043260 417790 302430
# 111710 234300 065710 086670 059210 024880 054040 038460 012790 263690
# 014200 009780 241520 122310 036640 052790 216050 208140 036670 339950
# 038680 158430 048430 115440 007370 024800 155650 094970 130580 054930
# 241790 224110 082210 212560 090410 250000 105760 094840 271830 053270
# 038010 010240 039420 092300 019540 100030 227950 122690 440290 067920
# 204020 088910 263920 263770 098120 263020 003310 019770 332370 246690
# 111870 066360 046310 025880 078590 340440 131090 267790 099410 290270
# 052460 020180 297570 362990 006920 080470 039310 042940 113810 154040
# 208350 043590 053060 335870
# For company code 041190, the predicted signal for the next day is: No Signal
# For company code 015750, the predicted signal for the next day is: No Signal
# For company code 215200, the predicted signal for the next day is: No Signal
# For company code 025980, the predicted signal for the next day is: No Signal
# For company code 095660, the predicted signal for the next day is: No Signal
# For company code 215000, the predicted signal for the next day is: No Signal
# For company code 290650, the predicted signal for the next day is: No Signal
# For company code 099320, the predicted signal for the next day is: No Signal
# For company code 006730, the predicted signal for the next day is: No Signal
# For company code 101160, the predicted signal for the next day is: No Signal
# For company code 023160, the predicted signal for the next day is: No Signal
# For company code 013030, the predicted signal for the next day is: No Signal
# For company code 043150, the predicted signal for the next day is: No Signal
# For company code 243070, the predicted signal for the next day is: No Signal
# For company code 297890, the predicted signal for the next day is: No Signal
# For company code 230360, the predicted signal for the next day is: No Signal
# For company code 035890, the predicted signal for the next day is: No Signal
# For company code 045100, the predicted signal for the next day is: No Signal
# For company code 041830, the predicted signal for the next day is: No Signal
# For company code 083450, the predicted signal for the next day is: No Signal
# For company code 018310, the predicted signal for the next day is: No Signal
# For company code 267980, the predicted signal for the next day is: No Signal
# For company code 060250, the predicted signal for the next day is: No Signal
# For company code 265520, the predicted signal for the next day is: No Signal
# For company code 126700, the predicted signal for the next day is: No Signal
# For company code 050890, the predicted signal for the next day is: Sell
# For company code 035600, the predicted signal for the next day is: No Signal
# For company code 051370, the predicted signal for the next day is: No Signal
# For company code 054950, the predicted signal for the next day is: No Signal
# For company code 299900, the predicted signal for the next day is: No Signal
# For company code 211050, the predicted signal for the next day is: No Signal
# For company code 148150, the predicted signal for the next day is: Buy
# For company code 118990, the predicted signal for the next day is: No Signal
# For company code 078150, the predicted signal for the next day is: No Signal
# For company code 108230, the predicted signal for the next day is: No Signal
# For company code 950170, the predicted signal for the next day is: No Signal
# For company code 054450, the predicted signal for the next day is: No Signal
# For company code 051500, the predicted signal for the next day is: No Signal
# For company code 052400, the predicted signal for the next day is: No Signal
# For company code 236200, the predicted signal for the next day is: Sell
# For company code 083310, the predicted signal for the next day is: No Signal
# For company code 190510, the predicted signal for the next day is: No Signal
# For company code 194700, the predicted signal for the next day is: No Signal
# For company code 377450, the predicted signal for the next day is: Sell
# For company code 023760, the predicted signal for the next day is: No Signal
# For company code 067280, the predicted signal for the next day is: No Signal
# For company code 046440, the predicted signal for the next day is: No Signal
# For company code 092730, the predicted signal for the next day is: No Signal
# For company code 136540, the predicted signal for the next day is: No Signal
# For company code 123410, the predicted signal for the next day is: No Signal
# For company code 214180, the predicted signal for the next day is: No Signal
# For company code 036190, the predicted signal for the next day is: No Signal
# For company code 023910, the predicted signal for the next day is: No Signal
# For company code 091580, the predicted signal for the next day is: No Signal
# For company code 298540, the predicted signal for the next day is: No Signal
# For company code 079960, the predicted signal for the next day is: No Signal
# For company code 009300, the predicted signal for the next day is: No Signal
# For company code 418470, the predicted signal for the next day is: No Signal
# For company code 023600, the predicted signal for the next day is: No Signal
# For company code 452400, the predicted signal for the next day is: Sell
# For company code 950190, the predicted signal for the next day is: No Signal
# For company code 203650, the predicted signal for the next day is: No Signal
# For company code 259630, the predicted signal for the next day is: No Signal
# For company code 285490, the predicted signal for the next day is: No Signal
# For company code 445180, the predicted signal for the next day is: No Signal
# For company code 038110, the predicted signal for the next day is: No Signal
# For company code 264450, the predicted signal for the next day is: No Signal
# For company code 033290, the predicted signal for the next day is: No Signal
# For company code 099440, the predicted signal for the next day is: No Signal
# For company code 060560, the predicted signal for the next day is: No Signal
# For company code 353810, the predicted signal for the next day is: Buy
# For company code 092460, the predicted signal for the next day is: No Signal
# For company code 066620, the predicted signal for the next day is: No Signal
# For company code 100700, the predicted signal for the next day is: No Signal
# For company code 382800, the predicted signal for the next day is: No Signal
# For company code 067900, the predicted signal for the next day is: No Signal
# For company code 066700, the predicted signal for the next day is: No Signal
# For company code 069510, the predicted signal for the next day is: No Signal
# For company code 013310, the predicted signal for the next day is: No Signal
# For company code 124560, the predicted signal for the next day is: No Signal
# For company code 137950, the predicted signal for the next day is: No Signal
# For company code 332570, the predicted signal for the next day is: No Signal
# For company code 021080, the predicted signal for the next day is: No Signal
# For company code 215360, the predicted signal for the next day is: No Signal
# For company code 066590, the predicted signal for the next day is: No Signal
# For company code 005990, the predicted signal for the next day is: No Signal
# For company code 058630, the predicted signal for the next day is: No Signal
# For company code 071200, the predicted signal for the next day is: No Signal
# For company code 053700, the predicted signal for the next day is: No Signal
# For company code 035610, the predicted signal for the next day is: No Signal
# For company code 011560, the predicted signal for the next day is: No Signal
# For company code 089850, the predicted signal for the next day is: No Signal
# For company code 142210, the predicted signal for the next day is: No Signal
# For company code 352090, the predicted signal for the next day is: No Signal
# For company code 036630, the predicted signal for the next day is: No Signal
# For company code 019590, the predicted signal for the next day is: Sell
# For company code 042500, the predicted signal for the next day is: No Signal
# For company code 043260, the predicted signal for the next day is: No Signal
# For company code 417790, the predicted signal for the next day is: No Signal
# For company code 302430, the predicted signal for the next day is: No Signal
# For company code 111710, the predicted signal for the next day is: No Signal
# For company code 234300, the predicted signal for the next day is: No Signal
# For company code 065710, the predicted signal for the next day is: No Signal
# For company code 086670, the predicted signal for the next day is: No Signal
# For company code 059210, the predicted signal for the next day is: No Signal
# For company code 024880, the predicted signal for the next day is: No Signal
# For company code 054040, the predicted signal for the next day is: No Signal
# For company code 038460, the predicted signal for the next day is: No Signal
# For company code 012790, the predicted signal for the next day is: No Signal
# For company code 263690, the predicted signal for the next day is: No Signal
# For company code 014200, the predicted signal for the next day is: Sell
# For company code 009780, the predicted signal for the next day is: No Signal
# For company code 241520, the predicted signal for the next day is: No Signal
# For company code 122310, the predicted signal for the next day is: No Signal
# For company code 036640, the predicted signal for the next day is: No Signal
# For company code 052790, the predicted signal for the next day is: No Signal
# For company code 216050, the predicted signal for the next day is: No Signal
# For company code 208140, the predicted signal for the next day is: No Signal
# For company code 036670, the predicted signal for the next day is: No Signal
# For company code 339950, the predicted signal for the next day is: No Signal
# For company code 038680, the predicted signal for the next day is: No Signal
# For company code 158430, the predicted signal for the next day is: No Signal
# For company code 048430, the predicted signal for the next day is: No Signal
# For company code 115440, the predicted signal for the next day is: Sell
# For company code 007370, the predicted signal for the next day is: No Signal
# For company code 024800, the predicted signal for the next day is: No Signal
# For company code 155650, the predicted signal for the next day is: No Signal
# For company code 094970, the predicted signal for the next day is: No Signal
# For company code 130580, the predicted signal for the next day is: No Signal
# For company code 054930, the predicted signal for the next day is: No Signal
# For company code 241790, the predicted signal for the next day is: No Signal
# For company code 224110, the predicted signal for the next day is: No Signal
# For company code 082210, the predicted signal for the next day is: No Signal
# For company code 212560, the predicted signal for the next day is: No Signal
# For company code 090410, the predicted signal for the next day is: No Signal
# For company code 250000, the predicted signal for the next day is: No Signal
# For company code 105760, the predicted signal for the next day is: No Signal
# For company code 094840, the predicted signal for the next day is: No Signal
# For company code 271830, the predicted signal for the next day is: No Signal
# For company code 053270, the predicted signal for the next day is: No Signal
# For company code 038010, the predicted signal for the next day is: No Signal
# For company code 010240, the predicted signal for the next day is: No Signal
# For company code 039420, the predicted signal for the next day is: No Signal
# For company code 092300, the predicted signal for the next day is: No Signal
# For company code 019540, the predicted signal for the next day is: No Signal
# For company code 100030, the predicted signal for the next day is: No Signal
# For company code 227950, the predicted signal for the next day is: No Signal
# For company code 122690, the predicted signal for the next day is: No Signal
# For company code 440290, the predicted signal for the next day is: No Signal
# For company code 067920, the predicted signal for the next day is: No Signal
# For company code 204020, the predicted signal for the next day is: No Signal
# For company code 088910, the predicted signal for the next day is: No Signal
# For company code 263920, the predicted signal for the next day is: No Signal
# For company code 263770, the predicted signal for the next day is: No Signal
# For company code 098120, the predicted signal for the next day is: No Signal
# For company code 263020, the predicted signal for the next day is: No Signal
# For company code 003310, the predicted signal for the next day is: No Signal
# For company code 019770, the predicted signal for the next day is: No Signal
# For company code 332370, the predicted signal for the next day is: Buy
# For company code 246690, the predicted signal for the next day is: No Signal
# For company code 111870, the predicted signal for the next day is: Sell
# For company code 066360, the predicted signal for the next day is: No Signal
# For company code 046310, the predicted signal for the next day is: No Signal
# For company code 025880, the predicted signal for the next day is: No Signal
# For company code 078590, the predicted signal for the next day is: No Signal
# For company code 340440, the predicted signal for the next day is: No Signal
# For company code 131090, the predicted signal for the next day is: No Signal
# For company code 267790, the predicted signal for the next day is: No Signal
# For company code 099410, the predicted signal for the next day is: No Signal
# For company code 290270, the predicted signal for the next day is: No Signal
# For company code 052460, the predicted signal for the next day is: No Signal
# For company code 020180, the predicted signal for the next day is: No Signal
# For company code 297570, the predicted signal for the next day is: No Signal
# For company code 362990, the predicted signal for the next day is: No Signal
# For company code 006920, the predicted signal for the next day is: No Signal
# For company code 080470, the predicted signal for the next day is: No Signal
# For company code 039310, the predicted signal for the next day is: No Signal
# For company code 042940, the predicted signal for the next day is: No Signal
# For company code 113810, the predicted signal for the next day is: No Signal
# For company code 154040, the predicted signal for the next day is: No Signal
# For company code 208350, the predicted signal for the next day is: No Signal
# For company code 043590, the predicted signal for the next day is: No Signal
# For company code 053060, the predicted signal for the next day is: No Signal
# For company code 335870, the predicted signal for the next day is: No Signal
#
# Signal Counts Summary:
# Sell (0): 8
# Buy (1): 3
# No Signal (2): 173
